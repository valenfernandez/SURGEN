# %% [markdown]
# https://www.earthdatascience.org/tutorials/introduction-to-leaflet-animated-maps/
#
# https://github.com/martoalalu/TfL-python-api
#
# https://rpubs.com/martinalalu/movilidad-urbana
